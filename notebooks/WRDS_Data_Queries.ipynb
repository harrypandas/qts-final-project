# %% [markdown]
# # WRDS Data Queries

# %%
import pandas as pd
import numpy as np
import quandl
import wrds

# %%
BrianBoonstraPrivateKeys['wrds']['username']
# Out:
# 'boonstra2022'

# %% [markdown]
# The following password-free login depends on having created a `~/.pgpass` file with with WRDS entries, as in
#
# ```
# wrds-pgdata.wharton.upenn.edu:9737:wrds:brianboonstra:<password>
# ```

# %%
db = wrds.Connection(
    wrds_username=BrianBoonstraPrivateKeys['wrds']['username'],
)
# Out:
# Loading library list...
# Done

# %%
db.describe_table(library="trace", table='trade_summary')
# Out:
# Approximately 16362568 rows in trace.trade_summary.
#                  name  nullable              type
# 0            trans_dt      True              DATE
# 1         bond_sym_id      True       VARCHAR(14)
# 2            cusip_id      True        VARCHAR(9)
# 3                bsym      True       VARCHAR(12)
# 4        sub_prd_type      True        VARCHAR(5)
# 5              wis_fl      True        VARCHAR(1)
# 6             high_pr      True  DOUBLE_PRECISION
# 7    high_yld_sign_cd      True        VARCHAR(1)
# 8            high_yld      True  DOUBLE_PRECISION
# 9              low_pr      True  DOUBLE_PRECISION
# 10    low_yld_sign_cd      True        VARCHAR(1)
# 11            low_yld      True  DOUBLE_PRECISION
# 12           close_pr      True  DOUBLE_PRECISION
# 13  close_yld_sign_cd      True        VARCHAR(1)
# 14          close_yld      True  DOUBLE_PRECISION
# 15     company_symbol      True        VARCHAR(6)

# %%
db.list_tables(library="trace")
# Out:
# ['absmasterfile',
#  'cmomasterfile',
#  'masterfile',
#  'mbsmasterfile',
#  'tbamasterfile',
#  'trace',
#  'trace_agency',
#  'trace_agency_names',
#  'trace_btds144a',
#  'trace_btds144a_names',
#  'trace_enhanced',
#  'trace_enhanced_names',
#  'trace_names',
#  'trace_spds144a_abs',
#  'trace_spds144a_abs_names',
#  'trace_spds144a_cmo',
#  'trace_spds144a_cmo_names',
#  'trace_spds_abs',
#  'trace_spds_abs_names',
#  'trace_spds_cmo',
#  'trace_spds_cmo_names',
#  'trace_spds_mbs',
#  'trace_spds_mbs_names',
#  'trace_spds_tba',
#  'trace_spds_tba_names',
#  'trade_summary',
#  'trade_summary_agency',
#  'trade_summary_btds144a',
#  'trade_summary_spds144a_abs',
#  'trade_summary_spds144a_cmo',
#  'trade_summary_spds_abs',
#  'trade_summary_spds_cmo',
#  'trade_summary_spds_mbs',
#  'trade_summary_spds_tba']

# %%
db.raw_sql("SELECT COUNT(*) FROM trace.trace", )
# Out:
#        count
# 0  179125244

# %%
single_row = db.raw_sql(
"""
SELECT * 
FROM trace.trace
ORDER BY TRD_EXCTN_DT DESC
LIMIT 1
"""
    , )

# %%
single_row.transpose()
# Out:
#                               0
# cusip_id              Y9T10PX26
# bond_sym_id         UOVE4359330
# company_symbol             UOVE
# bsym               BBG00CF2S0K9
# trd_exctn_dt         2020-09-30
# trd_exctn_tm              39565
# sub_prd_type               CORP
# trans_dt             2020-09-30
# msg_seq_nb                15031
# trc_st                        M
# wis_fl                     None
# cmsn_trd                   None
# remuneration                  N
# ascii_rptd_vol_tx        475000
# frmt_cd                       A
# rptd_pr                 101.862
# yld_sign_cd                None
# yld_pt                     None
# asof_cd                    None
# days_to_sttl_ct            None
# sale_cndtn_cd              None
# sale_cndtn2_cd             None
# spcl_trd_fl                None
# diss_rptg_side_cd          None
# side                          B
# chng_cd                       5
# rptd_high_pr               None
# high_yld_sign_cd           None
# high_yld_pt                None
# rptd_low_pr                None
# low_yld_sign_cd            None
# low_yld_pt                 None
# rptd_last_pr               None
# lsal_yld_sign_cd           None
# lsal_yld_pt                None
# orig_dis_dt                None
# orig_msg_seq_nb            None
# function                   None
# sttl_dt              2020-10-02
# rptg_party_type               D
# contra_party_type             C
# ats_indicator              None

# %%
some_traded_sql = """
SELECT 
 company_symbol, BOND_SYM_ID, cusip_id, RPTD_PR as price, 
 ASCII_RPTD_VOL_TX AS volm, FRMT_CD as quantity,
 TRD_EXCTN_DT as date, TRD_EXCTN_TM AS time_seconds
FROM trace.trace
WHERE TRD_EXCTN_DT > '2020-06-30' 
  AND cusip_id IS NOT NULL 

LIMIT 10
"""

# %%
some_trades = db.raw_sql(some_traded_sql, 
          date_cols=['date']
          )
some_trades
# Out:
#   company_symbol bond_sym_id   cusip_id    price     volm quantity       date  \
# 0            ABB  ABB3852125  00037BAB8  104.071    10000        A 2020-07-01
# 1            ABB  ABB3852125  00037BAB8  104.255    20000        A 2020-07-01
# 2            ABB  ABB3852142  00037BAC6  126.033  1000000        A 2020-07-01
# 3            ABB  ABB4615653  00037BAE2  106.743    60000        A 2020-07-01
# 4            ADT  ADT3991008  00101JAF3  100.263    50000        A 2020-07-01
# 5            ADT  ADT3991008  00101JAF3  100.163    50000        A 2020-07-01
# 6            ADT  ADT3991008  00101JAF3  100.163    50000        A 2020-07-01
# 7            ADT  ADT3991008  00101JAF3   99.595     5000        A 2020-07-01
# 8            ADT  ADT3991008  00101JAF3  100.635    50000        A 2020-07-01
# 9            ADT  ADT3991008  00101JAF3  100.335    50000        A 2020-07-01
#
#    time_seconds
# 0       55045.0
# 1       60714.0
# 2       56917.0
# 3       40517.0
# 4       34797.0
# 5       34797.0
# 6       34797.0
# 7       35182.0
# 8       38973.0
# 9       38973.0

# %%
some_cds = db.raw_sql(f"""
    SELECT DISTINCT ON (date, ticker)
      date, ticker, tenor, parspread, upfront, runningcoupon, cdsrealrecovery, cdsassumedrecovery, docclause, currency, tier, impliedrating 
      FROM markit.cds2023 
    WHERE ticker IN ('NFLX', 'LUV')
      AND docclause = 'MR14'
      AND currency = 'USD'
      AND tier = 'SNRFOR'
      AND tenor = '5Y'
    """, 
          date_cols=['date'])

# %%
some_cds
# Out:
#          date ticker tenor  parspread   upfront  runningcoupon  \
# 0  2023-01-02    LUV    5Y   0.011800  0.007882           0.01
# 1  2023-01-02   NFLX    5Y   0.014104  0.017842           0.01
# 2  2023-01-03    LUV    5Y   0.011923  0.008413           0.01
# 3  2023-01-03   NFLX    5Y   0.013705 -0.157973           0.05
# 4  2023-01-04    LUV    5Y   0.011588  0.006965           0.01
# 5  2023-01-04   NFLX    5Y   0.013388 -0.159725           0.05
# 6  2023-01-05    LUV    5Y   0.011484 -0.169099           0.05
# 7  2023-01-05   NFLX    5Y   0.013000  0.013108           0.01
# 8  2023-01-06    LUV    5Y   0.011058 -0.170856           0.05
# 9  2023-01-06   NFLX    5Y   0.012289  0.010005           0.01
# 10 2023-01-09    LUV    5Y   0.010650  0.002862           0.01
# 11 2023-01-09   NFLX    5Y   0.011923  0.008440           0.01
# 12 2023-01-10    LUV    5Y   0.010712 -0.173186           0.05
# 13 2023-01-10   NFLX    5Y   0.011620 -0.168666           0.05
# 14 2023-01-11    LUV    5Y   0.010611  0.002690           0.01
# 15 2023-01-11   NFLX    5Y   0.011398  0.006142           0.01
# 16 2023-01-12    LUV    5Y   0.010278 -0.175201           0.05
# 17 2023-01-12   NFLX    5Y   0.011180 -0.170761           0.05
# 18 2023-01-13    LUV    5Y   0.010319 -0.175321           0.05
# 19 2023-01-13   NFLX    5Y   0.011123  0.004951           0.01
# 20 2023-01-16    LUV    5Y   0.010318  0.001400           0.01
# 21 2023-01-16   NFLX    5Y   0.011102  0.004843           0.01
# 22 2023-01-17    LUV    5Y   0.010438 -0.174045           0.05
# 23 2023-01-17   NFLX    5Y   0.010947 -0.171646           0.05
# 24 2023-01-18    LUV    5Y   0.010334  0.001468           0.01
# 25 2023-01-18   NFLX    5Y   0.010724 -0.172806           0.05
# 26 2023-01-19    LUV    5Y   0.010645 -0.173419           0.05
# 27 2023-01-19   NFLX    5Y   0.011346  0.005919           0.01
# 28 2023-01-20    LUV    5Y   0.010565 -0.173605           0.05
# 29 2023-01-20   NFLX    5Y   0.010471  0.002074           0.01
# 30 2023-01-23    LUV    5Y   0.010396  0.001738           0.01
# 31 2023-01-23   NFLX    5Y   0.009916 -0.000369           0.01
# 32 2023-01-24    LUV    5Y   0.010366 -0.173677           0.05
# 33 2023-01-24   NFLX    5Y   0.009933 -0.175908           0.05
# 34 2023-01-25    LUV    5Y   0.010341  0.001497           0.01
# 35 2023-01-25   NFLX    5Y   0.010005  0.000022           0.01
# 36 2023-01-26    LUV    5Y   0.010239 -0.174436           0.05
# 37 2023-01-26   NFLX    5Y   0.009348 -0.178985           0.05
# 38 2023-01-27    LUV    5Y   0.010232 -0.174169           0.05
# 39 2023-01-27   NFLX    5Y   0.009146 -0.179684           0.05
# 40 2023-01-30    LUV    5Y   0.010444  0.001937           0.01
# 41 2023-01-30   NFLX    5Y   0.009371 -0.002758           0.01
# 42 2023-01-31    LUV    5Y   0.010275 -0.173222           0.05
# 43 2023-01-31   NFLX    5Y   0.008994 -0.179673           0.05
# 44 2023-02-01    LUV    5Y   0.010036 -0.174671           0.05
# 45 2023-02-01   NFLX    5Y   0.008546 -0.182218           0.05
# 46 2023-02-02    LUV    5Y   0.009558 -0.177340           0.05
# 47 2023-02-02   NFLX    5Y   0.008010 -0.008774           0.01
# 48 2023-02-03    LUV    5Y   0.009484 -0.002262           0.01
# 49 2023-02-03   NFLX    5Y   0.008011 -0.184939           0.05
# 50 2023-02-06    LUV    5Y   0.009659 -0.175630           0.05
# 51 2023-02-06   NFLX    5Y   0.008182 -0.183000           0.05
# 52 2023-02-07    LUV    5Y   0.009634 -0.175037           0.05
# 53 2023-02-07   NFLX    5Y   0.008144 -0.008088           0.01
#
#     cdsrealrecovery  cdsassumedrecovery docclause currency    tier  \
# 0          0.394398                 0.4      MR14      USD  SNRFOR
# 1          0.395980                 0.4      MR14      USD  SNRFOR
# 2          0.395723                 0.4      MR14      USD  SNRFOR
# 3          0.397143                 0.4      MR14      USD  SNRFOR
# 4          0.399644                 0.4      MR14      USD  SNRFOR
# 5          0.397487                 0.4      MR14      USD  SNRFOR
# 6          0.396126                 0.4      MR14      USD  SNRFOR
# 7          0.396650                 0.4      MR14      USD  SNRFOR
# 8          0.395856                 0.4      MR14      USD  SNRFOR
# 9          0.397129                 0.4      MR14      USD  SNRFOR
# 10         0.395835                 0.4      MR14      USD  SNRFOR
# 11         0.397129                 0.4      MR14      USD  SNRFOR
# 12         0.395486                 0.4      MR14      USD  SNRFOR
# 13         0.397487                 0.4      MR14      USD  SNRFOR
# 14         0.395457                 0.4      MR14      USD  SNRFOR
# 15         0.397487                 0.4      MR14      USD  SNRFOR
# 16         0.395804                 0.4      MR14      USD  SNRFOR
# 17         0.397129                 0.4      MR14      USD  SNRFOR
# 18         0.395073                 0.4      MR14      USD  SNRFOR
# 19         0.395980                 0.4      MR14      USD  SNRFOR
# 20         0.395423                 0.4      MR14      USD  SNRFOR
# 21         0.397129                 0.4      MR14      USD  SNRFOR
# 22         0.395038                 0.4      MR14      USD  SNRFOR
# 23         0.395980                 0.4      MR14      USD  SNRFOR
# 24         0.395003                 0.4      MR14      USD  SNRFOR
# 25         0.397129                 0.4      MR14      USD  SNRFOR
# 26         0.395769                 0.4      MR14      USD  SNRFOR
# 27         0.399975                 0.4      MR14      USD  SNRFOR
# 28         0.395455                 0.4      MR14      USD  SNRFOR
# 29         0.394975                 0.4      MR14      USD  SNRFOR
# 30         0.395804                 0.4      MR14      USD  SNRFOR
# 31         0.397129                 0.4      MR14      USD  SNRFOR
# 32         0.395073                 0.4      MR14      USD  SNRFOR
# 33         0.396650                 0.4      MR14      USD  SNRFOR
# 34         0.395833                 0.4      MR14      USD  SNRFOR
# 35         0.397767                 0.4      MR14      USD  SNRFOR
# 36         0.395076                 0.4      MR14      USD  SNRFOR
# 37         0.396000                 0.4      MR14      USD  SNRFOR
# 38         0.395000                 0.4      MR14      USD  SNRFOR
# 39         0.396667                 0.4      MR14      USD  SNRFOR
# 40         0.395417                 0.4      MR14      USD  SNRFOR
# 41         0.396667                 0.4      MR14      USD  SNRFOR
# 42         0.399583                 0.4      MR14      USD  SNRFOR
# 43         0.396000                 0.4      MR14      USD  SNRFOR
# 44         0.396122                 0.4      MR14      USD  SNRFOR
# 45         0.400000                 0.4      MR14      USD  SNRFOR
# 46         0.395856                 0.4      MR14      USD  SNRFOR
# 47         0.400000                 0.4      MR14      USD  SNRFOR
# 48         0.394586                 0.4      MR14      USD  SNRFOR
# 49         0.395980                 0.4      MR14      USD  SNRFOR
# 50         0.395737                 0.4      MR14      USD  SNRFOR
# 51         0.396000                 0.4      MR14      USD  SNRFOR
# 52         0.394574                 0.4      MR14      USD  SNRFOR
# 53         0.396650                 0.4      MR14      USD  SNRFOR
#
#    impliedrating
# 0            BBB
# 1            BBB
# 2            BBB
# 3            BBB
# 4            BBB
# 5            BBB
# 6            BBB
# 7            BBB
# 8            BBB
# 9            BBB
# 10           BBB
# 11           BBB
# 12           BBB
# 13           BBB
# 14           BBB
# 15           BBB
# 16           BBB
# 17           BBB
# 18           BBB
# 19           BBB
# 20           BBB
# 21           BBB
# 22           BBB
# 23           BBB
# 24           BBB
# 25           BBB
# 26           BBB
# 27           BBB
# 28           BBB
# 29           BBB
# 30           BBB
# 31           BBB
# 32           BBB
# 33           BBB
# 34           BBB
# 35           BBB
# 36           BBB
# 37           BBB
# 38           BBB
# 39           BBB
# 40           BBB
# 41           BBB
# 42           BBB
# 43           BBB
# 44           BBB
# 45           BBB
# 46           BBB
# 47           BBB
# 48           BBB
# 49           BBB
# 50           BBB
# 51           BBB
# 52           BBB
# 53           BBB
